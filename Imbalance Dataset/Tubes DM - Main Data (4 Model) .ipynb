# %% [markdown]
# # Deskripsi _Project_

# %% [markdown]
# &emsp;&emsp;Dataset ini bernama _default of credit card clients_ yang berasal dari _UCI Machine Learning Repository_. Dalam rentan sekitar tahun 2005, penerbit kartu kredit di Taiwan menghadapi krisis hutang tunai dan kartu kredit dan kenakalan tersebut diperkirakan akan mencapai puncaknya pada kuartal ketiga tahun 2006. Untuk meningkatkan pangsa pasar, bank penerbit kartu di Taiwan mengeluarkan lebih banyak uang tunai dan kartu kredit kepada pelamar yang tidak memenuhi syarat. Pada saat yang sama, sebagian besar pemegang kartu, terlepas dari kemampuan mereka membayar kembali, menggunakan kartu kredit secara berlebihan untuk konsumsi dan mengakumulasi hutang kartu kredit dan kartu tunai yang besar. Krisis tersebut menyebabkan pukulan terhadap kepercayaan pembiayaan konsumen dan ini merupakan tantangan besar bagi bank dan pemegang kartu.
#
# &emsp;&emsp;Bank perlu menentukan / mengklasifikasi konsumen mana saja yang diberikan kartu kredit dan memiliki kemampuan pembayaran agar mengurangi risiko rugi yang akan diterima oleh bank tersebut. Untuk deskripsi data secara detail adalah data pembayaran pada bulan Oktober 2005, dari sebuah bank penting (penerbit tunai dan kartu kredit) di Taiwan dan targetnya adalah pemegang kartu kredit bank tersebut. Label dataset yaitu pada pembayaran default (Ya = 1, Tidak = 0), kemudian atribut lainnya sebagai berikut:
# 1.	X1: Jumlah kredit yang diberikan (dolar NT): termasuk kredit konsumen individu dan kredit keluarganya (tambahan).
# 2.	X2: Jenis Kelamin (1 = laki-laki; 2 = perempuan).
# 3.	X3: Pendidikan (1 = sekolah pascasarjana; 2 = universitas; 3 = SMA; 4 = lain-lain).
# 4.	X4: Status perkawinan (1 = menikah; 2 = belum menikah; 3 = lain-lain).
# 5.	X5: Umur (tahun).
# 6.	X6 – X11: Sejarah pembayaran yang lalu, (dari April sampai September 2005) sebagai berikut:
#     - X6 = status pembayaran kembali pada September 2005.
#     - X7 = status pembayaran kembali pada Agustus 2005.
#     - X8 = status pembayaran kembali pada Juli 2005.
#     - X9 = status pembayaran kembali pada Juni 2005.
#     - X10 = status pembayaran kembali pada Mei 2005.
#     - X11 = status pembayaran kembali di bulan April 2005.
# Dengan skala pengukuran untuk status pembayaran kembali adalah:  −1 = bayar sepatutnya; 1 = penundaan pembayaran selama satu bulan; 2 = penundaan pembayaran selama dua bulan; …; 8 = penundaan pembayaran selama delapan bulan; 9 = penundaan pembayaran selama sembilan bulan ke atas.
# 7.	X12 – X17: Jumlah laporan tagihan (dolar NT), detailnya sebagai berikut:
#     - X12 = jumlah tagihan pada bulan September 2005.
#     - X13 = jumlah tagihan pada bulan Agustus 2005.
#     - X14 = jumlah tagihan pada bulan Juli 2005.
#     - X15 = jumlah tagihan pada bulan Juni 2005.
#     - X16 = jumlah tagihan pada bulan Mei 2005.
#     - X17 = jumlah tagihan pada bulan April 2005.
# 8.	X18 – X23: Jumlah pembayaran sebelumnya (dolar NT).
#     - X18 = jumlah yang dibayarkan pada bulan September 2005.
#     - X19 = jumlah yang dibayarkan pada bulan Agustus 2005.
#     - X20 = jumlah yang dibayarkan pada bulan Juli 2005.
#     - X21 = jumlah yang dibayarkan pada bulan Juni 2005.
#     - X22 = jumlah yang dibayarkan pada bulan Mei 2005.
#     - X23 = jumlah yang dibayarkan pada bulan April 2005.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Explorasi Data

# %%
# Load data dan melihat data awal
cc = pd.read_excel('default of credit card clients.xls')
cc.head()
# Out:
#   Unnamed: 0         X1   X2         X3        X4   X5     X6     X7     X8  \
# 0         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 1          1      20000    2          2         1   24      2      2     -1
# 2          2     120000    2          2         2   26     -1      2      0
# 3          3      90000    2          2         2   34      0      0      0
# 4          4      50000    2          2         1   37      0      0      0
#
#       X9  ...        X15        X16        X17       X18       X19       X20  \
# 0  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 1     -1  ...          0          0          0         0       689         0
# 2      0  ...       3272       3455       3261         0      1000      1000
# 3      0  ...      14331      14948      15549      1518      1500      1000
# 4      0  ...      28314      28959      29547      2000      2019      1200
#
# ...

# %%
cc.tail()
# Out:
#       Unnamed: 0      X1 X2 X3 X4  X5  X6  X7  X8  X9  ...    X15    X16  \
# 29996      29996  220000  1  3  1  39   0   0   0   0  ...  88004  31237
# 29997      29997  150000  1  3  2  43  -1  -1  -1  -1  ...   8979   5190
# 29998      29998   30000  1  2  2  37   4   3   2  -1  ...  20878  20582
# 29999      29999   80000  1  3  1  41   1  -1   0   0  ...  52774  11855
# 30000      30000   50000  1  2  1  46   0   0   0   0  ...  36535  32428
#
#          X17    X18    X19    X20   X21    X22   X23  Y
# 29996  15980   8500  20000   5003  3047   5000  1000  0
# 29997      0   1837   3526   8998   129      0     0  0
# 29998  19357      0      0  22000  4200   2000  3100  1
# 29999  48944  85900   3409   1178  1926  52964  1804  1
# 30000  15313   2078   1800   1430  1000   1000  1000  1
#
# [5 rows x 25 columns]

# %%
# Ukuran awal data
cc.shape
# Out:
# (30001, 25)

# %% [markdown]
# > Dari data awal terdapat baris 0 (baris pertama berupa keterangan dari **X1** sampai **X23**, baris ini tidak akan digunakan untuk proses selanjutnya.

# %%
label = cc.iloc[:1,:]
# print(label)
label.transpose()
# Out:
#                                      0
# Unnamed: 0                          ID
# X1                           LIMIT_BAL
# X2                                 SEX
# X3                           EDUCATION
# X4                            MARRIAGE
# X5                                 AGE
# X6                               PAY_0
# X7                               PAY_2
# X8                               PAY_3
# X9                               PAY_4
# X10                              PAY_5
# X11                              PAY_6
# X12                          BILL_AMT1
# X13                          BILL_AMT2
# X14                          BILL_AMT3
# X15                          BILL_AMT4
# X16                          BILL_AMT5
# X17                          BILL_AMT6
# X18                           PAY_AMT1
# X19                           PAY_AMT2
# X20                           PAY_AMT3
# X21                           PAY_AMT4
# X22                           PAY_AMT5
# ...

# %% [markdown]
# > Keterangan nama atribut pada dataset

# %%
cc.duplicated().sum()
# Out:
# 0

# %%
# Remove keterangan Xi, i=1,2,...,23
cc = cc.iloc[1:,1:]
cc.head()
# Out:
#        X1 X2 X3 X4  X5  X6 X7  X8  X9 X10  ...    X15    X16    X17   X18  \
# 1   20000  2  2  1  24   2  2  -1  -1  -2  ...      0      0      0     0
# 2  120000  2  2  2  26  -1  2   0   0   0  ...   3272   3455   3261     0
# 3   90000  2  2  2  34   0  0   0   0   0  ...  14331  14948  15549  1518
# 4   50000  2  2  1  37   0  0   0   0   0  ...  28314  28959  29547  2000
# 5   50000  1  2  1  57  -1  0  -1   0   0  ...  20940  19146  19131  2000
#
#      X19    X20   X21   X22   X23  Y
# 1    689      0     0     0     0  1
# 2   1000   1000  1000     0  2000  1
# 3   1500   1000  1000  1000  5000  0
# 4   2019   1200  1100  1069  1000  0
# 5  36681  10000  9000   689   679  0
#
# [5 rows x 24 columns]

# %%
# Ukuran data yang baru
cc.shape
# Out:
# (30000, 24)

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 1 to 30000
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      30000 non-null  object
#  1   X2      30000 non-null  object
#  2   X3      30000 non-null  object
#  3   X4      30000 non-null  object
#  4   X5      30000 non-null  object
#  5   X6      30000 non-null  object
#  6   X7      30000 non-null  object
#  7   X8      30000 non-null  object
#  8   X9      30000 non-null  object
#  9   X10     30000 non-null  object
#  10  X11     30000 non-null  object
#  11  X12     30000 non-null  object
#  12  X13     30000 non-null  object
#  13  X14     30000 non-null  object
#  14  X15     30000 non-null  object
#  15  X16     30000 non-null  object
#  16  X17     30000 non-null  object
#  17  X18     30000 non-null  object
#  18  X19     30000 non-null  object
#  19  X20     30000 non-null  object
#  20  X21     30000 non-null  object
# ...

# %%
cc.describe()
# Out:
#            X1     X2     X3     X4     X5     X6     X7     X8     X9    X10  \
# count   30000  30000  30000  30000  30000  30000  30000  30000  30000  30000
# unique     81      2      7      4     56     11     11     11     11     10
# top     50000      2      2      2     29      0      0      0      0      0
# freq     3365  18112  14030  15964   1605  14737  15730  15764  16455  16947
#
#         ...    X15    X16    X17    X18    X19    X20    X21    X22    X23  \
# count   ...  30000  30000  30000  30000  30000  30000  30000  30000  30000
# unique  ...  21548  21010  20604   7943   7899   7518   6937   6897   6939
# top     ...      0      0      0      0      0      0      0      0      0
# freq    ...   3195   3506   4020   5249   5396   5968   6408   6703   7173
#
#             Y
# count   30000
# unique      2
# top         0
# freq    23364
#
# [4 rows x 24 columns]

# %%
# Mengecek jumlah nilai unik pada setiap atribut
cc.nunique()
# Out:
# X1        81
# X2         2
# X3         7
# X4         4
# X5        56
# X6        11
# X7        11
# X8        11
# X9        11
# X10       10
# X11       10
# X12    22723
# X13    22346
# X14    22026
# X15    21548
# X16    21010
# X17    20604
# X18     7943
# X19     7899
# X20     7518
# X21     6937
# X22     6897
# X23     6939
# Y          2
# dtype: int64

# %%
# Cek missing value
cc.isnull().sum()
# Out:
# X1     0
# X2     0
# X3     0
# X4     0
# X5     0
# X6     0
# X7     0
# X8     0
# X9     0
# X10    0
# X11    0
# X12    0
# X13    0
# X14    0
# X15    0
# X16    0
# X17    0
# X18    0
# X19    0
# X20    0
# X21    0
# X22    0
# X23    0
# Y      0
# dtype: int64

# %% [markdown]
# ## Cek Keadaan Kelas

# %%
# Cek keadaan kelas
print(cc['Y'].value_counts())

# Plot dengan presentase
fig, ax = plt.subplots(figsize=(7,5))
name = ['No', 'Yes']
ax = cc['Y'].value_counts().plot(kind='bar')
ax.set_title('Perbandingan Data Penipuan dan yang Bukan', fontsize = 17)
ax.set_xticklabels (name, rotation = 0)

# menghitung presentase
totals = []
for i in ax.patches:
  totals.append(i.get_height())
total = sum(totals)
for i in ax.patches:  
  ax.text(i.get_x()+0.12, i.get_height()-i.get_height()/2, \
          str(round((i.get_height()/total)*100, 2))+'%', fontsize=15,
          color='white', weight = 'bold')    
plt.tight_layout()
# Out:
# 0    23364
# 1     6636
# Name: Y, dtype: int64

# %% [markdown]
# > Grafik menunjukkan bahwa dataset ini tidak seimbang (_imbalance dataset_), akan sulit mendapat hasil klasifikasi yang bagus. Sehingga perlu beberapa proses tambahan pada tahap ***Preprocessing Data***.

# %% [markdown]
# ## Cek Distribusi Data

# %%
# Convert type kolom numerik
col_num=[]
col_cat=[]
col = cc.columns[:cc.shape[1]-1]
for i in cc.columns:
  if cc[i].nunique() > 12:        
    cc[i] = pd.to_numeric(cc[i])
    col_num.append(i)
  else:
    col_cat.append(i)
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 1 to 30000
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      30000 non-null  int64
#  1   X2      30000 non-null  object
#  2   X3      30000 non-null  object
#  3   X4      30000 non-null  object
#  4   X5      30000 non-null  int64
#  5   X6      30000 non-null  object
#  6   X7      30000 non-null  object
#  7   X8      30000 non-null  object
#  8   X9      30000 non-null  object
#  9   X10     30000 non-null  object
#  10  X11     30000 non-null  object
#  11  X12     30000 non-null  int64
#  12  X13     30000 non-null  int64
#  13  X14     30000 non-null  int64
#  14  X15     30000 non-null  int64
#  15  X16     30000 non-null  int64
#  16  X17     30000 non-null  int64
#  17  X18     30000 non-null  int64
#  18  X19     30000 non-null  int64
#  19  X20     30000 non-null  int64
#  20  X21     30000 non-null  int64
# ...

# %%
print('atribut numerik:', col_num)
print('atribut kategorikal:',col_cat)
# Out:
# atribut numerik: ['X1', 'X5', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19', 'X20', 'X21', 'X22', 'X23']
# atribut kategorikal: ['X2', 'X3', 'X4', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'Y']

# %%
# g = sns.pairplot(cc, vars=col_num , hue='Y')

# %%
# # Plot Numerical Atribut and its distribution for each class
# sns.set(rc={'figure.figsize':(25,15)}, style='white')
# n = 1
# for col in col_num:
#     plt.subplot(3, 5, n)
#     n = n+1
#     sns.histplot(data=cc, x=col, hue='Y', kde=True)

# %% [markdown]
# > Grafik awal dari setiap atribut numerik menunjukkan distribusi yang kurang baik.

# %% [markdown]
# ## Cek Outlier

# %%
sns.set(style='white')
plt.rcParams['figure.figsize'] = (15, 15)
plt.suptitle('Cek Outlier',fontsize=25)
plt.subplots_adjust(wspace = 0.5, hspace= 0.3)

for i in range(len(col_num)):
  plt.subplot(3,5,i+1)
  plt.title(col_num[i])  
  sns.boxplot(x='Y', y=col_num[i],data=cc)

# %%
# cek jumlah outlier untuk tiap atribut numerik

print('Jumlah Outlier Awal')
for i in col_num:
  Q1 = cc[i].quantile(0.25)
  Q3 = cc[i].quantile(0.75)
  IQR = Q3 - Q1
  otl = abs(cc[cc[i] < (Q1 - 1.5 * IQR)].shape[0])+abs(cc[cc[i]>(Q3 + 1.5 * IQR)].shape[0])    
  print(i, ': %1d outlier data (%.2f'%(otl, otl/cc.shape[0]*100)+'%)')
# Out:
# Jumlah Outlier Awal
# X1 : 167 outlier data (0.56%)
# X5 : 272 outlier data (0.91%)
# X12 : 2400 outlier data (8.00%)
# X13 : 2395 outlier data (7.98%)
# X14 : 2469 outlier data (8.23%)
# X15 : 2622 outlier data (8.74%)
# X16 : 2725 outlier data (9.08%)
# X17 : 2693 outlier data (8.98%)
# X18 : 2745 outlier data (9.15%)
# X19 : 2714 outlier data (9.05%)
# X20 : 2598 outlier data (8.66%)
# X21 : 2994 outlier data (9.98%)
# X22 : 2945 outlier data (9.82%)
# X23 : 2958 outlier data (9.86%)

# %% [markdown]
# > Grafik Boxplot menunjukkan terdapat banyak ***Outlier*** pada setiap atribut numerik. Dari pengecekan selanjutnya, didapat bahwa ***Outlier*** berkisar **0,56%** sampai **9,98%** pada setiap atribut numerik. Karena cukup banyak, jika langsung dihilangkan mungkin dapat meghilangkan banyak informasi penting. Untuk itu, akan dilakukan _handle_ lebih lanjut pada tahap **_Preprocessing Data_**.

# %%
# transform cat data
for col in col_cat:
    cc[col] = pd.to_numeric(cc[col])
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 1 to 30000
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      30000 non-null  int64
#  1   X2      30000 non-null  int64
#  2   X3      30000 non-null  int64
#  3   X4      30000 non-null  int64
#  4   X5      30000 non-null  int64
#  5   X6      30000 non-null  int64
#  6   X7      30000 non-null  int64
#  7   X8      30000 non-null  int64
#  8   X9      30000 non-null  int64
#  9   X10     30000 non-null  int64
#  10  X11     30000 non-null  int64
#  11  X12     30000 non-null  int64
#  12  X13     30000 non-null  int64
#  13  X14     30000 non-null  int64
#  14  X15     30000 non-null  int64
#  15  X16     30000 non-null  int64
#  16  X17     30000 non-null  int64
#  17  X18     30000 non-null  int64
#  18  X19     30000 non-null  int64
#  19  X20     30000 non-null  int64
#  20  X21     30000 non-null  int64
# ...

# %%
# Convert Y to numerik
cc['Y'] = pd.to_numeric(cc['Y'])

# Plot korelasi
sns.set(style='white')
plt.rcParams['figure.figsize'] = (20,12)
sns.heatmap(cc.corr(), annot=True, linewidths=.5, cmap='coolwarm', center=0, vmin=-1, vmax=1)
plt.title('Korelasi diantara Atribut Numerik', fontsize = 30)
plt.show()

# %% [markdown]
# > Dari ***Heatmap*** terlihat tidak ada atribut yang memiliki korelasi yang menonjol untuk memberikan pengaruh pada label kelas.

# %% [markdown]
# # _Preprocessing_ Data

# %% [markdown]
# ## Transformasi Data

# %% [markdown]
# > Pada tahap sebelumnya diketahui bahwa banyak terdapat ***Outlier*** pada data. Untuk itu, akan dilakukan **Transformasi Data** agar jumlah ***Outlier*** berkurang dan distribusi data lebih baik. Tahapannya:
# 1. _Robust Scaling_, _scaling_ untuk menangani ***Outlier*** pada data dengan menggunakan _Quantile 1_ dan _Quantile 3_.
# 2. _Power Transform Scaling_, _scaling_ untuk membuat distribusi data menjadi lebih _Gaussian_ agar dapat digunakan lebih baik pada model nantinya.
# 3. _Min-Max Scaling_ _scaling_ untuk menyamakan batas menjadi diantara **0 - 1**.

# %%
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler

robust_trans = RobustScaler(quantile_range=(25, 75))
mm_trans = MinMaxScaler()
power_trans = PowerTransformer()

for i in col_num:    
  cc[i] = robust_trans.fit_transform(cc[[i]])  
  cc[i] = power_trans.fit_transform(cc[[i]])  
#   cc[i] = mm_trans.fit_transform(cc[[i]])

# %%
# cek jumlah outlier untuk tiap atribut numerik

print('Jumlah Outlier Setelah Transformasi Data')
for i in col_num:
  Q1 = cc[i].quantile(0.25)
  Q3 = cc[i].quantile(0.75)
  IQR = Q3 - Q1
  otl = abs(cc[cc[i] < (Q1 - 1.5 * IQR)].shape[0])+abs(cc[cc[i]>(Q3 + 1.5 * IQR)].shape[0])    
  print(i, ': %1d outlier data (%.2f'%(otl, otl/cc.shape[0]*100)+'%)')
# Out:
# Jumlah Outlier Setelah Transformasi Data
# X1 : 0 outlier data (0.00%)
# X5 : 0 outlier data (0.00%)
# X12 : 2 outlier data (0.01%)
# X13 : 4 outlier data (0.01%)
# X14 : 4 outlier data (0.01%)
# X15 : 6 outlier data (0.02%)
# X16 : 8 outlier data (0.03%)
# X17 : 295 outlier data (0.98%)
# X18 : 0 outlier data (0.00%)
# X19 : 0 outlier data (0.00%)
# X20 : 0 outlier data (0.00%)
# X21 : 0 outlier data (0.00%)
# X22 : 0 outlier data (0.00%)
# X23 : 0 outlier data (0.00%)

# %%
cc_atr = cc.iloc[:,:-1].copy()
for col in col_cat:
    if col != 'Y':
        cc_atr = cc_atr.drop(columns=[col], axis=1)
        
Q1 = cc_atr.quantile(0.25)
Q3 = cc_atr.quantile(0.75)
IQR = Q3 - Q1

cc_clean = cc_atr[~((cc_atr < (Q1 - 1.5 * IQR)) | (cc_atr > (Q3 + 1.5 * IQR))).any(axis=1)]
for i in col_num:
    cc_clean[i] = mm_trans.fit_transform(cc_clean[[i]])

# cc_clean['Y']=cc.Y

for col in col_num:
    cc[col] = cc_clean[col]
#     if col != 'Y':
    
cc = cc.dropna()
# cc.isnull().sum()
# cc.shape
print(cc.shape)
# cc = cc_clean
# Out:
# (29688, 24)
# <ipython-input-24-8737b2bb8bdd>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc_clean[i] = mm_trans.fit_transform(cc_clean[[i]])
# <ipython-input-24-8737b2bb8bdd>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc_clean[i] = mm_trans.fit_transform(cc_clean[[i]])
# <ipython-input-24-8737b2bb8bdd>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29688 entries, 1 to 30000
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      29688 non-null  float64
#  1   X2      29688 non-null  int64
#  2   X3      29688 non-null  int64
#  3   X4      29688 non-null  int64
#  4   X5      29688 non-null  float64
#  5   X6      29688 non-null  int64
#  6   X7      29688 non-null  int64
#  7   X8      29688 non-null  int64
#  8   X9      29688 non-null  int64
#  9   X10     29688 non-null  int64
#  10  X11     29688 non-null  int64
#  11  X12     29688 non-null  float64
#  12  X13     29688 non-null  float64
#  13  X14     29688 non-null  float64
#  14  X15     29688 non-null  float64
#  15  X16     29688 non-null  float64
#  16  X17     29688 non-null  float64
#  17  X18     29688 non-null  float64
#  18  X19     29688 non-null  float64
#  19  X20     29688 non-null  float64
#  20  X21     29688 non-null  float64
# ...

# %%
cc.head()
# Out:
#          X1  X2  X3  X4        X5  X6  X7  X8  X9  X10  ...       X15  \
# 1  0.037816   2   2   1  0.116197   2   2  -1  -1   -2  ...  0.383303
# 2  0.346796   2   2   2  0.188030  -1   2   0   0    0  ...  0.416557
# 3  0.267238   2   2   2  0.427351   0   0   0   0    0  ...  0.511481
# 4  0.143683   2   2   1  0.496492   0   0   0   0    0  ...  0.596990
# 5  0.143683   1   2   1  0.811516  -1   0  -1   0    0  ...  0.556142
#
#         X16       X17       X18       X19       X20       X21       X22  \
# 1  0.415816  0.324153  0.000000  0.137687  0.000000  0.000000  0.000000
# 2  0.460282  0.350993  0.000000  0.191073  0.216937  0.240958  0.000000
# 3  0.579159  0.439531  0.256429  0.266188  0.216937  0.240958  0.239838
# 4  0.673459  0.517685  0.314670  0.331033  0.251937  0.260071  0.253088
# 5  0.612405  0.461606  0.314670  0.866949  0.734816  0.741397  0.175056
#
#         X23  Y
# 1  0.000000  1
# 2  0.397727  1
# 3  0.624231  0
# 4  0.240663  0
# 5  0.173414  0
#
# ...

# %%
sns.set(style='white')
plt.rcParams['figure.figsize'] = (15, 15)
plt.suptitle('Cek Outlier Terakhir',fontsize=25)
plt.subplots_adjust(wspace = 0.5, hspace= 0.3)

for i in range(len(col_num)):
  plt.subplot(3,5,i+1)
  plt.title(col_num[i])  
  sns.boxplot(x='Y', y=col_num[i],data=cc)

# %% [markdown]
# > Setelah proses **Transformasi Data**, ***Outlier*** jauh berkurang sehingga, data sudah lebih baik untuk digunakan pada tahap selanjutnya.

# %%
# Plot korelasi
sns.set(style='white')
plt.rcParams['figure.figsize'] = (20,12)
sns.heatmap(cc.corr(), annot=True, linewidths=.5, cmap='coolwarm', center=0, vmin=-1, vmax=1)
plt.title('Korelasi diantara Atribut Numerik Akhir', fontsize = 30)
plt.show()

# %%
# #Plot Numerical Atribut and its distribution for each class
# sns.set(rc={'figure.figsize':(25,15)}, style='white')
# n = 1
# for col in col_num:
#     plt.subplot(3, 5, n)
#     n = n+1
#     sns.histplot(data=cc, x=col, hue='Y', kde=True)

# %% [markdown]
# > Setelah beberapa proses yang dilalui grafik menunjukkan distribusi atribut numerik yang lebih baik dari pada distribusi di awal

# %%
# g = sns.pairplot(cc, vars=col_num , hue='Y')

# %%
# cc[cc.isnull()==True]
cc.isnull().sum()
# Out:
# X1     0
# X2     0
# X3     0
# X4     0
# X5     0
# X6     0
# X7     0
# X8     0
# X9     0
# X10    0
# X11    0
# X12    0
# X13    0
# X14    0
# X15    0
# X16    0
# X17    0
# X18    0
# X19    0
# X20    0
# X21    0
# X22    0
# X23    0
# Y      0
# dtype: int64

# %% [markdown]
# ## _One Hot Encoding Categorical Data_

# %%
# # Get one hot encoding of columns B
# cc_ohe = cc.copy()
# cc_ohe = cc_ohe.drop('Y', axis=1)

# for col in col_cat:
#     if col != 'Y':
#         one_hot = pd.get_dummies(cc[col], prefix=col)    
#         cc_ohe = cc_ohe.drop(col, axis = 1)    
#         cc_ohe = cc_ohe.join(one_hot)

# print(cc_ohe.shape)
# cc_ohe.head()

# %% [markdown]
# ## PCA

# %%
# from sklearn.decomposition import PCA

# # 95% of variance
# pca = PCA(n_components = 0.99)
# pca_data=cc.copy()
# pca_data = pca_data.drop('Y', axis=1)
# pca.fit(pca_data)
# pca_95 = pca.transform(pca_data)
# print('N Component: {}'.format(pca_95.shape))

# %%
# cc_pca_95 = pd.DataFrame(data=pca_95, columns = ['X'+str(i+1)+' baru' for i in range(pca_95.shape[1])])                                                                
# cc_pca_95.head()

# %% [markdown]
# ## Feature Selection

# %%
# cc_feature_selection = cc[['X6', 'X7', 'X8', 'X9', 'X10', 'X11']]
# cc_feature_selection_ohe = cc_feature_selection.copy()
# for col in cc_feature_selection.columns:    
#     one_hot = pd.get_dummies(cc[col], prefix=col)    
#     cc_feature_selection_ohe = cc_feature_selection_ohe.drop(col, axis = 1)    
#     cc_feature_selection_ohe = cc_feature_selection_ohe.join(one_hot)
# cc_feature_selection_ohe.head()

# %% [markdown]
# ## Splitting Data

# %%
# pip install imbalanced-learn

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %%
x = cc.iloc[:,:-1]
y = cc.iloc[:,-1:]

# # OHE Data
# # x = cc.iloc[:,:-1]
# y_ohe = cc_ohe.iloc[:,cc_ohe.columns.get_loc('Y'):cc_ohe.columns.get_loc('Y')+1]
# x_ohe = cc_ohe.copy()
# x_ohe = x_ohe.drop(columns=['Y'], axis=1)
# print(cc_ohe.shape, x.shape)
# x.head()
# # cc_ohe.columns.get_loc('Y')
# # cc_ohe.columns

# %%
x_train, x_tes, y_train, y_tes = train_test_split(x, y, stratify=y, test_size=0.2, random_state=42)
# x_train, x_tes, y_train, y_tes = train_test_split(cc_pca_95, y, test_size=0.2, random_state=42)
# x_train, x_tes, y_train, y_tes = train_test_split(x_ohe, y_ohe, test_size=0.2, random_state=42)
# x_train, x_tes, y_train, y_tes = train_test_split(cc_ohe_pca, y_ohe, test_size=0.2, random_state=42)
# x_train, x_tes, y_train, y_tes = train_test_split(cc_feature_selection, y_ohe, test_size=0.2, random_state=42)
# x_train, x_tes, y_train, y_tes = train_test_split(cc_feature_selection_ohe, y_ohe, test_size=0.3, random_state=42)

# %% [markdown]
# > Data dibagi menjadi dua bagian, yaitu ***80% Data Training*** dan ***20% Data Testing***.

# %% [markdown]
# ## SMOTE

# %%
# Cek keadaan kelas
print(y_train.value_counts())

# Plot dengan presentase
fig, ax = plt.subplots(figsize=(7,5))
name = ['No', 'Yes']
ax = y_train.value_counts().plot(kind='bar')
ax.set_title('Y Train Awal', fontsize = 17)
ax.set_xticklabels (name, rotation = 0)

# menghitung presentase
totals = []
for i in ax.patches:
  totals.append(i.get_height())
total = sum(totals)
for i in ax.patches:  
  ax.text(i.get_x()+0.12, i.get_height()-i.get_height()/2, \
          str(round((i.get_height()/total)*100, 2))+'%', fontsize=15,
          color='white', weight = 'bold')    
plt.tight_layout()
# Out:
# Y
# 0    18501
# 1     5249
# dtype: int64

# %% [markdown]
# > Untuk _menghandle_ data yang tidak seimbang dapat dilakukan dengan manipulasi agar data menjadi lebih seimbang. Untuk itu pada tahap ini akan meimlpementasikan metode ***Synthetic Minority Over-samplingTechnique (SMOTE)***, metode yang populer diterapkan dalam menangani ketidakseimbangan kelas. Teknik ini mensintesis sampel baru dari kelas minoritas untuk menyeimbangkan dataset dengan cara membuat instance baru dari minority class dengan pembentukan convex kombanasi dari instances yang saling berdekatan.
# [ref 1](https://www.analyticsvidhya.com/blog/2020/10/overcoming-class-imbalance-using-smote-techniques/), [ref_2](https://www.analyticsvidhya.com/blog/2020/07/10-techniques-to-deal-with-class-imbalance-in-machine-learning/), &
# [ref_3](https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/)

# %%
y_tes.value_counts()
# Out:
# Y
# 0    4626
# 1    1312
# dtype: int64

# %%
# !pip install imbalanced-learn

# %%
import imblearn
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import NearMiss
from imblearn.combine import SMOTETomek
from imblearn.over_sampling import SMOTE 
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import SVMSMOTE
from collections import Counter

# %%
# oversample = BorderlineSMOTE(random_state=42)
# # over = SMOTE(sampling_strategy=0.1)
# # under = RandomUnderSampler(sampling_strategy=0.5)
# x_train, y_train = oversample.fit_resample(x_train, y_train)

# %%
# instantiating over and under sampler
over = SMOTETomek(sampling_strategy=0.75, random_state=42)
under = NearMiss(sampling_strategy=1) #random_state=42

print('Keadaan y_train awal oversampling & undesampling: \n{}\n'.format(y_train['Y'].value_counts()))

# oversampling to minority class
x_train, y_train = over.fit_resample(x_train, y_train)
print('Keadaan y_train setelah oversampling: \n{}\n'.format(y_train['Y'].value_counts()))

# # undersampling
# x_train, y_train = under.fit_resample(x_train, y_train)
# print('Keadaan y_train setelah oversampling & undesampling: \n{}'.format(y_train['Y'].value_counts()))
# Out:
# Keadaan y_train awal oversampling & undesampling:
# 0    18501
# 1     5249
# Name: Y, dtype: int64
#
# Keadaan y_train setelah oversampling:
# 0    17999
# 1    13373
# Name: Y, dtype: int64

# %%
m_name = []
model = []
conf_mat = []
report = []
acc = []
pres = []
rec = []
f1 = []
roc_auc = []

# %% [markdown]
# # 4. Proses Klasifikasi

# %% [markdown]
# ## 4.1 KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

model1 = KNeighborsClassifier(n_neighbors=2)
model.append(model1)
model1.fit(x_train, y_train)
y_pred = model1.predict(x_tes)

rep = metrics.classification_report(y_pred, y_tes)
report.append(rep)
print(rep)

mat = metrics.confusion_matrix(y_tes, y_pred)
conf_mat.append(mat)
print(mat)
# Out:
# <ipython-input-48-8be571b651a1>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   model1.fit(x_train, y_train)
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84      4679
#            1       0.41      0.43      0.42      1259
#
#     accuracy                           0.75      5938
#    macro avg       0.63      0.63      0.63      5938
# weighted avg       0.75      0.75      0.75      5938
#
# [[3907  719]
#  [ 772  540]]

# %%
m_name.append('KNN')
acc.append(metrics.accuracy_score(y_tes, y_pred))
pres.append(metrics.precision_score(y_tes, y_pred))
rec.append(metrics.recall_score(y_tes, y_pred))
f1.append(metrics.f1_score(y_tes, y_pred))
roc_auc.append(metrics.roc_auc_score(y_tes, y_pred))
print('Akurasi:', metrics.accuracy_score(y_tes, y_pred))
print('Presisi:', metrics.precision_score(y_tes, y_pred))
print('Recall:', metrics.recall_score(y_tes, y_pred))
print('F1-Score', metrics.f1_score(y_tes, y_pred))
print('ROC-AUC', metrics.roc_auc_score(y_tes, y_pred))
# Out:
# Akurasi: 0.7489053553384978
# Presisi: 0.4289118347895155
# Recall: 0.4115853658536585
# F1-Score 0.4200700116686114
# ROC-AUC 0.6280797559921125

# %% [markdown]
# ## 4.2 Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

model2 = RandomForestClassifier(random_state=42)
model.append(model2)
model2.fit(x_train, y_train)
y_pred = model2.predict(x_tes)

rep = metrics.classification_report(y_pred, y_tes)
report.append(rep)
# report[1] = rep
print(rep)

mat = metrics.confusion_matrix(y_tes, y_pred)
conf_mat.append(mat)
# conf_mat[1] = mat
print(mat)
# Out:
# <ipython-input-50-a091f0aa03ac>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model2.fit(x_train, y_train)
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.87      4765
#            1       0.49      0.55      0.52      1173
#
#     accuracy                           0.80      5938
#    macro avg       0.69      0.70      0.69      5938
# weighted avg       0.81      0.80      0.80      5938
#
# [[4096  530]
#  [ 669  643]]

# %%
m_name.append('Random Forest')
# m_name[1] = ('Random Forest')
# acc[1] = metrics.accuracy_score(y_tes, y_pred)
# pres[1] = metrics.precision_score(y_tes, y_pred)
# rec[1] = metrics.recall_score(y_tes, y_pred)
# f1[1] = metrics.f1_score(y_tes, y_pred)
acc.append(metrics.accuracy_score(y_tes, y_pred))
pres.append(metrics.precision_score(y_tes, y_pred))
rec.append(metrics.recall_score(y_tes, y_pred))
f1.append(metrics.f1_score(y_tes, y_pred))
roc_auc.append(metrics.roc_auc_score(y_tes, y_pred))
print('Akurasi:', metrics.accuracy_score(y_tes, y_pred))
print('Presisi:', metrics.precision_score(y_tes, y_pred))
print('Recall:', metrics.recall_score(y_tes, y_pred))
print('F1-Score', metrics.f1_score(y_tes, y_pred))
print('ROC-AUC-Score', metrics.roc_auc_score(y_tes, y_pred))
# Out:
# Akurasi: 0.7980801616705961
# Presisi: 0.5481670929241261
# Recall: 0.49009146341463417
# F1-Score 0.5175050301810865
# ROC-AUC-Score 0.6877608203368026

# %% [markdown]
# ## 4.3 CatBoost

# %%
# !pip install catboost

# %%
from catboost import CatBoostClassifier

# %%
model3 = CatBoostClassifier(
#     loss_function = 'CrossEntropy',
    custom_loss= ['AUC', 'F1', 'Accuracy', 'BalancedErrorRate', 'Recall', 'Precision'],
    random_seed=42,    
#     boosting_type='Ordered',
    auto_class_weights= 'SqrtBalanced',
#     iterations = 1500, #2129, #5000, #795, #210, #707, #20000, #662, #10000, #7500, #1000
    verbose = 200,
#     depth = 10,
#     l2_leaf_reg = 1,
    learning_rate = 0.075 #0.01 ##0.01 #0.001 #0.0075    
    
)

# %%
model3.fit(
    x_train, y_train,    
    eval_set=(x_tes, y_tes),    
    use_best_model=True,    
    plot=True)
# Out:
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
# ...

# %%
y_pred = model3.predict(x_tes)

rep = metrics.classification_report(y_pred, y_tes)
report.append(rep)
# report[2] = rep
print(rep)

mat = metrics.confusion_matrix(y_tes, y_pred)
conf_mat.append(mat)
# conf_mat[2] = mat
print(mat)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89      4972
#            1       0.46      0.62      0.53       966
#
#     accuracy                           0.82      5938
#    macro avg       0.69      0.74      0.71      5938
# weighted avg       0.85      0.82      0.83      5938
#
# [[4262  364]
#  [ 710  602]]

# %%
m_name.append('CatBoost')
acc.append(metrics.accuracy_score(y_tes, y_pred))
pres.append(metrics.precision_score(y_tes, y_pred))
rec.append(metrics.recall_score(y_tes, y_pred))
f1.append(metrics.f1_score(y_tes, y_pred))
roc_auc.append(metrics.roc_auc_score(y_tes, y_pred))
# acc[2] = metrics.accuracy_score(y_tes, y_pred)
# pres[2] = metrics.precision_score(y_tes, y_pred)
# rec[2] = metrics.recall_score(y_tes, y_pred)
# f1[2] = metrics.f1_score(y_tes, y_pred)
print('Akurasi:', metrics.accuracy_score(y_tes, y_pred))
print('Presisi:', metrics.precision_score(y_tes, y_pred))
print('Recall:', metrics.recall_score(y_tes, y_pred))
print('F1-Score', metrics.f1_score(y_tes, y_pred))
print('ROC AUC-Score', metrics.roc_auc_score(y_tes, y_pred))
# Out:
# Akurasi: 0.8191310205456382
# Presisi: 0.6231884057971014
# Recall: 0.45884146341463417
# F1-Score 0.5285338015803336
# ROC AUC-Score 0.6900778869170016

# %% [markdown]
# ## 4.4 SVM

# %%
from sklearn.svm import SVC

model4 = SVC(C=0.0009, kernel='linear', random_state=42)#C=0.01,  random_state=42)#C=0.1, kernel='linear')
model.append(model4)
model4.fit(x_train, y_train)
y_pred = model4.predict(x_tes)

rep = metrics.classification_report(y_pred, y_tes)
report.append(rep)
print(rep)

mat = metrics.confusion_matrix(y_tes, y_pred)
conf_mat.append(mat)
print(mat)
# Out:
# D:\Installan Apps\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      4703
#            1       0.52      0.56      0.54      1235
#
#     accuracy                           0.80      5938
#    macro avg       0.70      0.71      0.71      5938
# weighted avg       0.81      0.80      0.80      5938
#
# [[4079  547]
#  [ 624  688]]

# %%
m_name.append('SVM')
acc.append(metrics.accuracy_score(y_tes, y_pred))
pres.append(metrics.precision_score(y_tes, y_pred))
rec.append(metrics.recall_score(y_tes, y_pred))
f1.append(metrics.f1_score(y_tes, y_pred))
roc_auc.append(metrics.roc_auc_score(y_tes, y_pred))
print('Akurasi:', metrics.accuracy_score(y_tes, y_pred))
print('Presisi:', metrics.precision_score(y_tes, y_pred))
print('Recall:', metrics.recall_score(y_tes, y_pred))
print('F1-Score', metrics.f1_score(y_tes, y_pred))
print('ROC AUC-Score', metrics.roc_auc_score(y_tes, y_pred))
# Out:
# Akurasi: 0.8027955540586056
# Presisi: 0.557085020242915
# Recall: 0.524390243902439
# F1-Score 0.5402434236356498
# ROC AUC-Score 0.7030727700273112

# %% [markdown]
# > Bayes Optimization
# [Ref_1](https://thuijskens.github.io/2016/12/29/bayesian-optimisation/)
# [Ref_2](https://scikit-optimize.github.io/stable/auto_examples/sklearn-gridsearchcv-replacement.html#advanced-example)
# [Ref_3](https://www.youtube.com/watch?v=jtRPxRnOXnk)

# %% [markdown]
# # Evaluasi

# %% [markdown]
# ## _Confusion Matrix_

# %%
plt.figure(figsize=(16,3))

# plt.suptitle("Confusion Matrix",fontsize=25)
plt.subplots_adjust(wspace = 0.5, hspace=0.8)

for i in range(4):
  plt.subplot(1,4,i+1)
  plt.title(m_name[i], size=22)
  sns.heatmap(conf_mat[i], annot=True ,fmt='d',cbar=False, cmap='vlag',
            center=0, annot_kws={"size": 20})

# %% [markdown]
# ## Grafik Metric

# %%
plt.figure(figsize=(20,8))
plt.ylim((0,1))
plt.plot(m_name, acc, 'r', marker='o', label='Akurasi')
plt.plot(m_name, pres, 'g', marker='^', label='Presisi')
plt.plot(m_name, rec, 'b', marker='v', label='Recall')
plt.plot(m_name, f1, 'k', marker='*', label='F1-Score')
plt.plot(m_name, roc_auc, 'm', marker='+', label='ROC-AUC Score')
plt.xlabel('Metode Klasifikasi', size=15)
plt.ylabel('Nilainya', size=15)
plt.title('Grafik Hasil Beberapa Metric Terhadap Metode-Metode Klasifikasi yang Digunakan', size=24)
plt.legend()

# %% [markdown]
# ## Tabel Metric Evaluasi

# %%
acc_r = [round(e, 2) for e in acc]
pres_r = [round(e, 2) for e in pres]
rec_r = [round(e, 2) for e in rec]
f1_r = [round(e, 2) for e in f1]
roc_auc_r = [round(e, 2) for e in roc_auc]

hasil = {
    'Akurasi': acc_r,
    'Presisi': pres_r,
    'Recall': rec_r,
    'F1-Score': f1_r,
    'ROC-AUC Score': roc_auc_r
}

hasil = pd.DataFrame(hasil, index=m_name)
hasil.sort_values(by=['Akurasi', 'F1-Score'], ascending=False)
# Out:
#                Akurasi  Presisi  Recall  F1-Score  ROC-AUC Score
# CatBoost          0.82     0.62    0.46      0.53           0.69
# SVM               0.80     0.56    0.52      0.54           0.70
# Random Forest     0.80     0.55    0.49      0.52           0.69
# KNN               0.75     0.43    0.41      0.42           0.63

# %%
metrics.matthews_corrcoef(y_pred, y_tes)
# Out:
# 0.41517429044905013
